# %%
# !pip install pytube
# !pip install gTTS
# !pip install youtube-downloader
# !pip install speechrecognition
# Out:
# ...
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ------------- ------------------------ 20.5/57.6 kB 330.3 kB/s eta 0:00:01
#      -------------------- ----------------- 30.7/57.6 kB 330.3 kB/s eta 0:00:01
#      -------------------- ----------------- 30.7/57.6 kB 330.3 kB/s eta 0:00:01
#      -------------------- ----------------- 30.7/57.6 kB 330.3 kB/s eta 0:00:01
#      -------------------- ----------------- 30.7/57.6 kB 330.3 kB/s eta 0:00:01
#      --------------------------- ---------- 41.0/57.6 kB 122.9 kB/s eta 0:00:01
#      -------------------------------------- 57.6/57.6 kB 151.8 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/97.9 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/97.9 kB ? eta -:--:--
#      --------------- ---------------------- 41.0/97.9 kB 487.6 kB/s eta 0:00:01
#      --------------- ---------------------- 41.0/97.9 kB 487.6 kB/s eta 0:00:01
# ...

# %%
# !pip install youtube_transcript_api

# %%
pip install librosa
# Out:
# ...
#      ---------------------------------------- 0.0/253.0 kB ? eta -:--:--
#      - -------------------------------------- 10.2/253.0 kB ? eta -:--:--
#      ---- -------------------------------- 30.7/253.0 kB 435.7 kB/s eta 0:00:01
#      ---- -------------------------------- 30.7/253.0 kB 435.7 kB/s eta 0:00:01
#      ---- -------------------------------- 30.7/253.0 kB 435.7 kB/s eta 0:00:01
#      ---- -------------------------------- 30.7/253.0 kB 435.7 kB/s eta 0:00:01
#      -------- ---------------------------- 61.4/253.0 kB 181.6 kB/s eta 0:00:02
#      ---------- -------------------------- 71.7/253.0 kB 206.9 kB/s eta 0:00:01
#      ---------------- ------------------- 112.6/253.0 kB 284.4 kB/s eta 0:00:01
#      ---------------- ------------------- 112.6/253.0 kB 284.4 kB/s eta 0:00:01
#      ---------------- ------------------- 112.6/253.0 kB 284.4 kB/s eta 0:00:01
#      -------------------- --------------- 143.4/253.0 kB 266.2 kB/s eta 0:00:01
# ...

# %%
pip install torch
# Out:
# ...
#      ---------------------------------------- 0.0/172.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/172.4 MB ? eta -:--:--
#      -------------------------------------- 0.0/172.4 MB 435.7 kB/s eta 0:06:36
#      -------------------------------------- 0.0/172.4 MB 435.7 kB/s eta 0:06:36
#      -------------------------------------- 0.0/172.4 MB 435.7 kB/s eta 0:06:36
#      -------------------------------------- 0.0/172.4 MB 435.7 kB/s eta 0:06:36
#      -------------------------------------- 0.0/172.4 MB 122.9 kB/s eta 0:23:23
#      -------------------------------------- 0.1/172.4 MB 196.3 kB/s eta 0:14:38
#      -------------------------------------- 0.1/172.4 MB 273.1 kB/s eta 0:10:31
#      -------------------------------------- 0.1/172.4 MB 273.1 kB/s eta 0:10:31
#      -------------------------------------- 0.1/172.4 MB 273.1 kB/s eta 0:10:31
#      -------------------------------------- 0.1/172.4 MB 258.0 kB/s eta 0:11:08
# ...

# %%
import os
import urllib.request
import youtube_dl
import librosa
import torch
from pytube import YouTube
from pytube.exceptions import RegexMatchError
import speech_recognition as sr
from youtube_transcript_api import YouTubeTranscriptApi

# %%
# Fetch YouTube transcript
def fetch_youtube_transcript(youtube_video):
    try:
        video_id = youtube_video.split("=")[1]
        transcript = YouTubeTranscriptApi.get_transcript(video_id)
        result = ""
        for entry in transcript:
            result += ' ' + entry['text']
        return result
    except RegexMatchError:
        print("Error: English captions not found for the video.")
        return None

# %%
'''
import librosa

# Replace 'your_audio_file.wav' with the path to your audio file
audio_file_path = 'D:\audio\soong.wav'

# Load the audio file and get the audio samples (y) and the sampling rate (sr)
y, sr = librosa.load(audio_file_path)
'''
# Out:
# "\nimport librosa\n\n# Replace 'your_audio_file.wav' with the path to your audio file\naudio_file_path = 'D:\\project_118\\soong.wav'\n\n# Load the audio file and get the audio samples (y) and the sampling rate (sr)\ny, sr = librosa.load(audio_file_path)\n"

# %%
'''
# Extract audio data from a local video
def extract_audio_data(local_video_path):
    audio_data, sample_rate = librosa.load(local_video_path, sr=None)
    return audio_data, sample_rate

# Replace 'E:\project_118\song.mp4' with the actual file path of your local video
local_video_path = f'F:\movies\John Wick 4 (2023)2.9GB'

try:
    audio_data, sample_rate = extract_audio_data(local_video_path)
    print("Audio data shape:", audio_data.shape)
    print("Sample rate:", sample_rate)
except Exception as e:
    print("Error:", e)
    '''
# Out:
# '\n# Extract audio data from a local video\ndef extract_audio_data(local_video_path):\n    audio_data, sample_rate = librosa.load(local_video_path, sr=None)\n    return audio_data, sample_rate\n\n# Replace \'E:\\project_118\\song.mp4\' with the actual file path of your local video\nlocal_video_path = f\'F:\\movies\\John Wick 4 (2023)2.9GB\'\n\ntry:\n    audio_data, sample_rate = extract_audio_data(local_video_path)\n    print("Audio data shape:", audio_data.shape)\n    print("Sample rate:", sample_rate)\nexcept Exception as e:\n    print("Error:", e)\n    '

# %%
pip install nltk
# Out:
# ...
#      ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#       --------------------------------------- 0.0/1.5 MB 435.7 kB/s eta 0:00:04
#       --------------------------------------- 0.0/1.5 MB 435.7 kB/s eta 0:00:04
#       --------------------------------------- 0.0/1.5 MB 435.7 kB/s eta 0:00:04
#       --------------------------------------- 0.0/1.5 MB 435.7 kB/s eta 0:00:04
#      - -------------------------------------- 0.0/1.5 MB 122.9 kB/s eta 0:00:12
#      - -------------------------------------- 0.1/1.5 MB 196.9 kB/s eta 0:00:08
#      -- ------------------------------------- 0.1/1.5 MB 285.2 kB/s eta 0:00:05
#      -- ------------------------------------- 0.1/1.5 MB 285.2 kB/s eta 0:00:05
#      -- ------------------------------------- 0.1/1.5 MB 285.2 kB/s eta 0:00:05
#      --- ------------------------------------ 0.1/1.5 MB 266.2 kB/s eta 0:00:06
# ...

# %%
# Text preprocessing
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

def text_preprocessing(text):
    # Convert text to lowercase
    text = text.lower()

    # Remove special characters and punctuation
    text = re.sub(r'[^\w\s]', '', text)

    # Remove numbers
    text = re.sub(r'\d+', '', text)

    # Tokenize the text into individual words
    words = nltk.word_tokenize(text)

    # Remove stop words
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]

    # Lemmatize the words
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]

    # Join the words back into a single string
    text = ' '.join(words)

    # Remove extra whitespaces
    text = re.sub(r'\s+', ' ', text).strip()

    return text
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\shrih\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\shrih\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\shrih\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Text to voice conversion
from gtts import gTTS
output_file ="D:\audio\output_files"

def text_to_voice_conversion(text, output_file):
    try:
        # Create a gTTS object with the text and language (English)
        tts = gTTS(text=text, lang='en', slow=False)

        # Save the speech audio to a file
        tts.save(output_file)

        return True, "Text-to-voice conversion is successful."
    except Exception as e:
        return False, f"Error in text-to-voice conversion: {str(e)}"

# %%
preprocessed_text = "This is a sample text for text-to-voice conversion."
output_file = "output_audio.mp3"

success, message = text_to_voice_conversion(preprocessed_text, output_file)

if success:
    print(message)
else:
    print(message)
# Out:
# Text-to-voice conversion is successful.

# %%
pip install torchaudio
# Out:
# ...
#      ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#       --------------------------------------- 0.0/2.1 MB 435.7 kB/s eta 0:00:05
#       --------------------------------------- 0.0/2.1 MB 435.7 kB/s eta 0:00:05
#       --------------------------------------- 0.0/2.1 MB 435.7 kB/s eta 0:00:05
#       --------------------------------------- 0.0/2.1 MB 435.7 kB/s eta 0:00:05
#       --------------------------------------- 0.0/2.1 MB 130.7 kB/s eta 0:00:16
#      - -------------------------------------- 0.1/2.1 MB 181.6 kB/s eta 0:00:12
#      - -------------------------------------- 0.1/2.1 MB 249.8 kB/s eta 0:00:09
#      -- ------------------------------------- 0.1/2.1 MB 284.4 kB/s eta 0:00:08
#      -- ------------------------------------- 0.1/2.1 MB 284.4 kB/s eta 0:00:08
#      -- ------------------------------------- 0.1/2.1 MB 232.2 kB/s eta 0:00:09
# ...

# %%
# Audio preprocessing
import torchaudio

def audio_preprocessing(audio_data, sample_rate, n_mels=128, n_fft=400, hop_length=160):
    # Convert audio data to mel spectrogram
    mel_spectrogram = librosa.feature.melspectrogram(y=audio_data, sr=sample_rate, n_mels=n_mels, n_fft=n_fft, hop_length=hop_length)
    # Convert mel spectrogram to decibel (log scale)
    mel_spectrogram_db = librosa.power_to_db(mel_spectrogram, ref=np.max)
    # Normalize the mel spectrogram to values between 0 and 1
    mel_spectrogram_normalized = (mel_spectrogram_db - mel_spectrogram_db.min()) / (mel_spectrogram_db.max() - mel_spectrogram_db.min())
    # Convert mel spectrogram to tensor
    mel_spectrogram_tensor = torch.tensor(mel_spectrogram_normalized)

    return mel_spectrogram_tensor, sample_rate

# %%
def preprocessing_pipeline(youtube_link=None, local_video_path=None):
    if youtube_link:
        # Fetch YouTube transcript
        video_id = youtube_link.split("=")[1]
        transcript_text = fetch_youtube_transcript(youtube_link)
        # Perform text preprocessing
        preprocessed_text = text_preprocessing(transcript_text)
        # Perform text to voice conversion and save audio
        output_file = "output_audio.wav"  # Change this to the desired output file path
        text_to_voice_conversion(preprocessed_text, output_file)
        # Set audio_data to None to avoid UnboundLocalError when returning
        preprocessed_audio = None
        sample_rate = None
    elif local_video_path:
        # Extract audio data from a local video
        audio_data, sample_rate = extract_audio_data(local_video_path)
        # Convert audio data to text using ASR
        transcript_text = convert_audio_to_text(audio_data, sample_rate)
        # Perform text preprocessing
        preprocessed_text = text_preprocessing(transcript_text)
        # Perform text to voice conversion and save audio
        output_file = "output_audio.wav"  # Change this to the desired output file path
        text_to_voice_conversion(preprocessed_text, output_file)
        # Perform audio preprocessing
        preprocessed_audio, sample_rate = audio_preprocessing(audio_data, sample_rate)
        # Perform feature engineering
        # Your feature engineering code here
    else:
        raise ValueError("Either youtube_link or local_video_path must be provided.")

    return preprocessed_audio, preprocessed_text

# %%
# Example usage for online video with transcript
youtube_video = "https://www.youtube.com/watch?v=WnipnOcDkx8"
preprocessed_audio, preprocessed_text = preprocessing_pipeline(youtube_link=youtube_video)
